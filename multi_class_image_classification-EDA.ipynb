# %%
# importing the necessary packages
import os

import cv2
from PIL import Image
import numpy as np

import matplotlib.pyplot as plt
import pandas as pd
import scipy
from tqdm import tqdm

# %matplotlib inline

# %%
# assigning the file to a variable
label=pd.read_csv("/Users/rohitbohra/Documents/aptos2019-blindness-detection/label.csv")

# %%
# printing the shape of the file
print(label.shape)
# Out:
# (929, 3)

# %%
# count of the classes in the file
label['diagnosis'].hist()
label['diagnosis'].value_counts()
# Out:
# 0    467
# 2    232
# 1    100
# 4     73
# 3     57
# Name: diagnosis, dtype: int64

# %%
# assigning the .csv file to a variable.
label=pd.read_csv("/Users/rohitbohra/Documents/aptos2019-blindness-detection/label.csv")
# dropping the unnecessary column from the dataframe
label=label.drop(['Unnamed: 0'], axis=1)
list(label.columns)
# Out:
# ['id_code', 'diagnosis']

# %%
# viewing all the images in the folder
count=1
for i in label['id_code']:  
    if count<5:
        img = cv2.imread(f'/Users/rohitbohra/Documents/aptos2019-blindness-detection/train_images/'+i)
        plt.imshow(img)
        plt.show()
        count+=1
